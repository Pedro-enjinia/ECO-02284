# %%
"""
Programa converte_001
Descrição: Este programa converte uma medida inserida pelo usuário em metros para milímetros.
Autor: Pedro J. Tomazini
Data: 08/04/2026
Versão: 0.0.1
"""
# Out:
# '\nPrograma converte_001\nDescrição: Este programa converte uma medida inserida pelo usuário em metros para milímetros.\nAutor: Pedro J. Tomazini\nData: 08/04/2026\nVersão: 0.0.1\n'

# %%
# Alocação de memória

m = 0.0
i = 0

# %%
# Entrada e processamento de dados

while i==0:
    try:
        m = float(input("Insira uma medida em metros: "))
        if m>0:
            mv = m*1000 
            i = 1
        else:
            print("Insira um valor valido!")
    except:
        print("Insira um valor valido!")
# Out:
# Insira uma medida em metros:  sdad
# Insira um valor valido!
# Insira uma medida em metros:  sdad
# Insira um valor valido!
# Insira uma medida em metros:  2

# %%
# Saída de dados

print(f"O valor digitado em milimetros eh: {mv:.2f} mm")
# Out:
# O valor digitado em milimetros eh: 2000.00 mm
